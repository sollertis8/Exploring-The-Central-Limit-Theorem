# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10, 0.5, 10000) 

# Let’s make histograms for the two groups. 

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %% [markdown]
# The populations are not normal. Next, take a sample of 100 from each population and plot them.

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1')
plt.hist(sample2, alpha=0.5, label='sample 2')

plt.legend(loc='upper right')

plt.show()

print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

diff=sample2.mean() - sample1.mean()

print(diff)
# Out:
# 2.02
# 4.85
# 1.3189389675
# 1.65755844543
# 2.83

# %%
size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])

# The squared standard deviations are divided by the sample size and summed, then we take
# the square root of the sum. 
diff_se = sum(sd ** 2 / size) ** 0.5  

#The difference between the means divided by the standard error: T-value.  
print(diff/diff_se)
# Out:
# 13.3599108873

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=13.292943493721953, pvalue=7.0576822680475861e-29)

# %% [markdown]
# Increasing the sample sizes from 100 to 1000, I expect to see the shape of the histograms to look more similar to that of the original populations.

# %%
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1')
plt.hist(sample2, alpha=0.5, label='sample 2')

plt.legend(loc='upper right')

plt.show()

print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

diff=sample2.mean() - sample1.mean()

print(diff)
# Out:
# 1.992
# 4.909
# 1.24335674688
# 1.55393661389
# 2.917

# %% [markdown]
# As suspected, the shape of the samples more adequately represent their respective populations.  If we significantly decrease the sample sizes, I expect to see shapes that do not adequately represent the populations.

# %%
sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1')
plt.hist(sample2, alpha=0.5, label='sample 2')

plt.legend(loc='upper right')

plt.show()

print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

diff=sample2.mean() - sample1.mean()

print(diff)
# Out:
# 2.7
# 4.95
# 1.22882057274
# 1.90984292548
# 2.25

# %% [markdown]
# As suspected, the samples do not represent the populations accurately.

# %%
pop1 = np.random.binomial(10, 0.3, 10000)
sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1')
plt.hist(sample2, alpha=0.5, label='sample 2')

plt.legend(loc='upper right')

plt.show()

print(ttest_ind(sample2, sample1, equal_var=False))

print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

diff=sample2.mean() - sample1.mean()

print(diff)
# Out:
# Ttest_indResult(statistic=3.068618954414188, pvalue=0.0039977309654109392)
# 3.5
# 4.8
# 1.39642400438
# 1.20830459736
# 1.3

# %%
pop1 = np.random.binomial(10, 0.4, 10000)
sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1')
plt.hist(sample2, alpha=0.5, label='sample 2')

plt.legend(loc='upper right')

plt.show()

print(ttest_ind(sample2, sample1, equal_var=False))

print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

diff=sample2.mean() - sample1.mean()

print(diff)
# Out:
# Ttest_indResult(statistic=1.807690943157672, pvalue=0.079460411337206258)
# 4.0
# 4.95
# 1.87082869339
# 1.32193040664
# 0.95

# %% [markdown]
# After changing the p of the population, the t-value decreases and the p-value increases.

# %%
pop1 = np.random.poisson(5, 10000)
pop2 = np.random.poisson(7, 10000) 


plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1')
plt.hist(sample2, alpha=0.5, label='sample 2')

plt.legend(loc='upper right')

plt.show()

print(ttest_ind(sample2, sample1, equal_var=False))

print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

diff=sample2.mean() - sample1.mean()

print(diff)
# Out:
# Ttest_indResult(statistic=18.242352893465231, pvalue=8.1602186360031761e-69)
# 4.994
# 7.0
# 2.29738198826
# 2.60806441638
# 2.006

# %% [markdown]
# From the samples taken from our poisson distributions, we can see that the larger the sample size, the more accurately the sample mean values represent the population values.  Conversely, the smaller the sample sizes, the less representative they are of the population.
